# %%
import pandas as p
data = p.read_csv('covid.csv', header = 0)

# %%
data
# Out:
#       Sex          Age Vaccine Type           Facility Type  Number of Doses  \
# 0       F  20-29 years      Moderna  Public Health Provider                1
# 1       F  20-29 years      Moderna  Public Health Provider                1
# 2       F  20-29 years       Pfizer                Hospital                1
# 3       F  20-29 years       Pfizer  Public Health Provider                1
# 4       F  30-39 years      Moderna  Public Health Provider                2
# ...    ..          ...          ...                     ...              ...
# 10861   M  60-69 years       Pfizer                Hospital                1
# 10862   M  60-69 years       Pfizer                Hospital                1
# 10863   M  60-69 years       Pfizer                Hospital                1
# 10864   M  60-69 years       Pfizer                Hospital                1
# 10865   M  70-79 years       Pfizer                Hospital                1
#
#        Week     Month  Year Data as of
# ...

# %%
data[:]['Age']
# Out:
# 0        20-29 years
# 1        20-29 years
# 2        20-29 years
# 3        20-29 years
# 4        30-39 years
#             ...
# 10861    60-69 years
# 10862    60-69 years
# 10863    60-69 years
# 10864    60-69 years
# 10865    70-79 years
# Name: Age, Length: 10866, dtype: object

# %%
counts = data['Age'].value_counts

# %%
counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        20-29 years
# 1        20-29 years
# 2        20-29 years
# 3        20-29 years
# 4        30-39 years
#             ...
# 10861    60-69 years
# 10862    60-69 years
# 10863    60-69 years
# 10864    60-69 years
# 10865    70-79 years
# Name: Age, Length: 10866, dtype: object>
