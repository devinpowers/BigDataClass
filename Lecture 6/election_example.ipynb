# %%
import pandas as pd
data = pd.read_csv('P00000001-MI.csv',index_col=False)
data.head()
# Out:
#      cmte_id    cand_id                    cand_nm         contbr_nm  \
# 0  C00574624  P60006111  Cruz, Rafael Edward 'Ted'    JEFFERIS, JOEL
# 1  C00575795  P00003392    Clinton, Hillary Rodham   DODGSON, YVONNE
# 2  C00577130  P60007168           Sanders, Bernard   KINGSLEY, DAVID
# 3  C00575795  P00003392    Clinton, Hillary Rodham      WEEKS, BRIAN
# 4  C00575795  P00003392    Clinton, Hillary Rodham  MENDOZA, ALBERTO
#
#   contbr_city contbr_st  contbr_zip            contbr_employer  \
# 0    ROCKFORD        MI   493417847                    NETJETS
# 1        ALTO        MI   493029352                        NaN
# 2   KALAMAZOO        MI   490096510                       NONE
# 3   MC MILLAN        MI   498539211              SELF-EMPLOYED
# 4     HASLETT        MI   488408651  MICHIGAN STATE UNIVERSITY
#
#         contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc  \
# 0                   PILOT                  5        01-APR-16          NaN
# 1                 RETIRED                100        13-APR-16          NaN
# 2                 RETIRED                200        05-MAR-16          NaN
# 3  FUNDRAISING CONSULTANT                500        19-APR-16          NaN
# 4               PROFESSOR                 50        01-APR-16          NaN
#
#   memo_cd                            memo_text form_tp  file_num  \
# 0     NaN                                  NaN   SA17A   1077664
# 1       X               * HILLARY VICTORY FUND    SA18   1091718
# 2     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404
# 3       X               * HILLARY VICTORY FUND    SA18   1091718
# 4       X               * HILLARY VICTORY FUND    SA18   1091718
#
#          tran_id election_tp
# 0  SA17A.1534865       P2016
# 1       C4718508       P2016
# 2    VPF7BKW3PX8       P2016
# 3       C4731520       P2016
# 4       C4671580       P2016

# %%
data.describe(include='all').transpose()
# Out:
#                     count  unique                                  top  \
# cmte_id            161096      24                            C00575795
# cand_id            161096      24                            P00003392
# cand_nm            161096      24              Clinton, Hillary Rodham
# contbr_nm          161096   36720                      NAGEL, PATRICIA
# contbr_city        161091    1217                            ANN ARBOR
# contbr_st          161096       1                                   MI
# contbr_zip         161085     NaN                                  NaN
# contbr_employer    136015   10342                              RETIRED
# contbr_occupation  160013    5632                              RETIRED
# contb_receipt_amt  161096     NaN                                  NaN
# contb_receipt_dt   161096     638                            12-JUL-16
# receipt_desc         1718      24                               Refund
# memo_cd             29839       1                                    X
# memo_text           61340      91  * EARMARKED CONTRIBUTION: SEE BELOW
# form_tp            161096       3                                SA17A
# file_num           161096     NaN                                  NaN
# tran_id            161096  160713                            C10763192
# election_tp        160604       4                                P2016
#
#                      freq         mean          std          min          25%  \
# cmte_id             68754          NaN          NaN          NaN          NaN
# cand_id             68754          NaN          NaN          NaN          NaN
# cand_nm             68754          NaN          NaN          NaN          NaN
# contbr_nm             324          NaN          NaN          NaN          NaN
# contbr_city         13901          NaN          NaN          NaN          NaN
# contbr_st          161096          NaN          NaN          NaN          NaN
# contbr_zip            NaN  4.20546e+08  1.66414e+08            0  4.81034e+08
# contbr_employer     24493          NaN          NaN          NaN          NaN
# contbr_occupation   43233          NaN          NaN          NaN          NaN
# contb_receipt_amt     NaN       98.746      333.904        -5400           15
# contb_receipt_dt     1712          NaN          NaN          NaN          NaN
# receipt_desc          879          NaN          NaN          NaN          NaN
# memo_cd             29839          NaN          NaN          NaN          NaN
# memo_text           46431          NaN          NaN          NaN          NaN
# form_tp            131350          NaN          NaN          NaN          NaN
# file_num              NaN   1.0959e+06      26034.1  1.00394e+06  1.07766e+06
# tran_id                 3          NaN          NaN          NaN          NaN
# election_tp        108211          NaN          NaN          NaN          NaN
#
#                            50%          75%          max
# cmte_id                    NaN          NaN          NaN
# cand_id                    NaN          NaN          NaN
# cand_nm                    NaN          NaN          NaN
# contbr_nm                  NaN          NaN          NaN
# contbr_city                NaN          NaN          NaN
# contbr_st                  NaN          NaN          NaN
# contbr_zip         4.83042e+08  4.90064e+08    4.997e+08
# contbr_employer            NaN          NaN          NaN
# contbr_occupation          NaN          NaN          NaN
# contb_receipt_amt           27           80        10800
# contb_receipt_dt           NaN          NaN          NaN
# receipt_desc               NaN          NaN          NaN
# memo_cd                    NaN          NaN          NaN
# memo_text                  NaN          NaN          NaN
# form_tp                    NaN          NaN          NaN
# file_num           1.09414e+06  1.11904e+06  1.13417e+06
# tran_id                    NaN          NaN          NaN
# election_tp                NaN          NaN          NaN

# %%
print 'Number of rows = ', data.size
print 'Number of duplicate rows = ', sum(data.duplicated())
print 'Number of rows with missing values = ', data.size - data.dropna().size
# Out:
# Number of rows =  2899728
# Number of duplicate rows =  0
# Number of rows with missing values =  2888568

# %%
for name, values in data.iteritems():
    print name, sum(values.isnull()), type(values.ix[0])
# Out:
# cmte_id 0 <type 'str'>
# cand_id 0 <type 'str'>
# cand_nm 0 <type 'str'>
# contbr_nm 0 <type 'str'>
# contbr_city 5 <type 'str'>
# contbr_st 0 <type 'str'>
# contbr_zip 11 <type 'numpy.float64'>
# contbr_employer 25081 <type 'str'>
# contbr_occupation 1083 <type 'str'>
# contb_receipt_amt 0 <type 'numpy.float64'>
# contb_receipt_dt 0 <type 'str'>
# receipt_desc 159378 <type 'float'>
# memo_cd 131257 <type 'float'>
# memo_text 99756 <type 'float'>
# form_tp 0 <type 'str'>
# file_num 0 <type 'numpy.int64'>
# tran_id 0 <type 'str'>
# election_tp 492 <type 'str'>

# %%
% matplotlib inline
data.contb_receipt_amt.plot.hist()

# %%
(data.contb_receipt_amt>0).value_counts()
# Out:
# True     159754
# False      1342
# Name: contb_receipt_amt, dtype: int64

# %%
data = data[data.contb_receipt_amt>0]
candidates = data.groupby('cand_nm')['contb_receipt_amt'].sum()
candidates
# Out:
# cand_nm
# Bush, Jeb                    1056414.50
# Carson, Benjamin S.          1045001.24
# Christie, Christopher J.       25125.00
# Clinton, Hillary Rodham      6600680.23
# Cruz, Rafael Edward 'Ted'    1053076.91
# Fiorina, Carly                104021.00
# Graham, Lindsey O.             43135.00
# Huckabee, Mike                  8575.00
# Jindal, Bobby                  11300.00
# Johnson, Gary                  79323.22
# Kasich, John R.               441546.10
# Lessig, Lawrence                3450.00
# McMullin, Evan                 30257.50
# O'Malley, Martin Joseph        35601.00
# Pataki, George E.                500.00
# Paul, Rand                    200953.99
# Perry, James R. (Rick)           350.00
# Rubio, Marco                  823488.92
# Sanders, Bernard             2076123.02
# Santorum, Richard J.            2491.98
# Stein, Jill                    19947.56
# Trump, Donald J.             2763179.00
# Walker, Scott                 114830.00
# Webb, James Henry Jr.           4800.00
# Name: contb_receipt_amt, dtype: float64
